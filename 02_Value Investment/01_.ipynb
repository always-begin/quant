# %%
import os, sys
import pandas as pd
import numpy as np
from datetime import datetime
sys.path.append('../')
from method import *
import finterstellar as fs

# %%
df =fs.fn_single(token, symbol='COST', window='T')

df.tail(3)
# Out:
#                  Revenue          COGS  Gross Profit          SG&A  \
# 2022-08-31  2.291870e+11  2.017850e+11  2.740200e+10  1.951100e+10
# 2022-11-30  2.317200e+11  2.040370e+11  2.768300e+10  1.985300e+10
# 2023-02-28  2.343900e+11  2.061050e+11  2.828500e+10  2.034300e+10
#
#             Operating Income    Net Income    EPS        EBITDA          EBIT  \
# 2022-08-31      7.891000e+09  5.873000e+09  13.23  9.892000e+09  7.891000e+09
# 2022-11-30      7.830000e+09  5.938000e+09  13.37  9.842000e+09  7.830000e+09
# 2023-02-28      7.942000e+09  6.051000e+09  13.63  9.891000e+09  7.942000e+09
#
#                  Shares  ...  Long Term Liabilities  Total Liabilities  \
# 2022-08-31  443651000.0  ...           1.152100e+10       4.351900e+10
# 2022-11-30  443837000.0  ...           1.148400e+10       4.455100e+10
# 2023-02-28  443877000.0  ...           1.153300e+10       4.404900e+10
#
#             Shareholders Equity  Depreciation  Operating Cash Flow  \
# ...
