# %% [markdown]
# # Short Term Investment
#
# ## MACD 이동 평균 수렴 발산 지수
#
# Moving Average Converagence Divergence
#
# 이동 편균선 사이 관계에서 추세 변화를 찾는 지표
#
# 이동 편균 선은 과거의 데이터 이므로 실제 추이를 계산하는데 있어서 후행적이다
#
# 이를 개선 하기 위해
#
# EMA(Exponential Moving Average) 사용
#
# ```
# EMA = 종가 x 배율 + EMA (전날) x (1 배율)
# ```
#
# **MACD**는 단기 평균 - 장기 평균
#
# `MACD` = EMA(12) - EMA(26)
#
# `MACD signal` = EMA(MACD, 9)
#
# `MACD Oscillator`  = `MACD` - `MACD signal`
#
#
# ![picture 1](../images/fc5f63f0415e032af44995d834c07735431836f533f710e9f5871458abe29df7.png)
#
# ## MACD 투자 전략

# %%
import os, sys
import pandas as pd
import numpy as np
from datetime import datetime
sys.path.append('../')
from stock import *

# %%
msf = get_price("MSFT", datetime(2022, 3, 23), datetime(2022, 12, 31))
print(msf.head(5))

draw_chart(dataframe=msf, right=["MSFT"])
# Out:
#              MSFT
# 2022-03-23 299.49
# 2022-03-24 304.10
# 2022-03-25 303.68
# 2022-03-28 310.70
# 2022-03-29 315.41

# %%
macd_msf= get_macd(msf)
add_signal_df(macd_msf, 'macd_oscillator',0,0)
draw_chart(macd_msf, left = 'MSFT', right ='position_chart')
# Out:
# factor : MSFT
# macd output_df : Index(['MSFT', 'macd', 'macd_signal', 'macd_oscillator'], dtype='object')
# signal columns : Index(['MSFT', 'macd', 'macd_signal', 'macd_oscillator', 'trade', 'position',
#        'position_chart'],
#       dtype='object')

# %%
macd_msf_result,_ = get_evaluate_column(macd_msf)
draw_trade_results(macd_msf_result)
# Out:
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# factor : MSFT
# CAGR: -39.50%
# Accumulated return: -30.52%
# Average return: -3.51%
# Benchmark return : -19.92%
# Number of trades: 10
# Number of win: 2
# Hit ratio: 20.00%
# Investment period: 0.8yrs
# Sharpe ratio: -1.35
# MDD: -33.01%
# Benchmark MDD: -32.07%
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
# Font 'default' does not have a glyph for '\u2212' [U+2212], substituting with a dummy symbol.
